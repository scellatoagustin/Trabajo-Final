# %% [markdown]
# <a href="https://colab.research.google.com/github/scellatoagustin/Trabajo-Final/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar el dataset

df = pd.read_csv("Cancer_Data.csv")

# Mostrar las primeras filas del dataset
print(df.head())

# Información del dataset
print(df.info())

# Descripción estadística
print(df.describe())

# Verificar nombres de columnas
print(df.columns)

# Supongamos que después de verificar, encontramos que las columnas son 'radius_mean', 'texture_mean', 'perimeter_mean'
columns_to_scale = ['radius_mean', 'texture_mean', 'perimeter_mean']

# Verificar si estas columnas están en el DataFrame
for column in columns_to_scale:
    if column not in df.columns:
        raise KeyError(f"La columna {column} no existe en el DataFrame")

# Escalar las columnas numéricas
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[columns_to_scale] = scaler.fit_transform(df[columns_to_scale])

# Verificar la limpieza
print(df.head())
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Verificar valores faltantes
df.isnull().sum()

# Eliminar columnas irrelevantes o con muchos valores faltantes (si las hay)
# df = df.drop(['columnas_irrelevantes'], axis=1)

# Codificar variables categóricas (si las hay)
# df['variable_categórica'] = df['variable_categórica'].map({'valor1': 0, 'valor2': 1})

# Escalar variables numéricas (usa los nombres de columnas correctos de tu dataset)
from sklearn.preprocessing import StandardScaler

# Verificar nombres de columnas
print(df.columns)

# Supongamos que las columnas que necesitas escalar son 'mean radius', 'mean texture', y 'mean perimeter'
columns_to_scale = ['mean radius', 'mean texture', 'mean perimeter']

# Verificar si estas columnas están en el DataFrame
for column in columns_to_scale:
    if column not in df.columns:
      raise KeyError(f"La columna {column} no existe en el DataFrame")

# Escalar las columnas numéricas
scaler = StandardScaler()
df[columns_to_scale] = scaler.fit_transform(df[columns_to_scale])

# Verificar la limpieza
df.head()
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-5dd2c915742b> in <cell line: 20>()
#      20 for column in columns_to_scale:
#      21     if column not in df.columns:
# ...

# %%
# Selección de características relevantes
X = df.drop(['diagnosis'], axis=1)  # 'diagnosis' es la variable objetivo
y = df['diagnosis']

# Dividir los datos en conjuntos de entrenamiento y prueba
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc

# Entrenar el modelo
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)

# Evaluar el modelo
y_pred = log_reg.predict(X_test)
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))

# Curva ROC
y_pred_prob = log_reg.predict_proba(X_test)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

# Entrenar el modelo
tree_clf = DecisionTreeClassifier()
tree_clf.fit(X_train, y_train)

# Evaluar el modelo
y_pred_tree = tree_clf.predict(X_test)
print(classification_report(y_test, y_pred_tree))
print(confusion_matrix(y_test, y_pred_tree))

# Curva ROC
y_pred_prob_tree = tree_clf.predict_proba(X_test)[:,1]
fpr_tree, tpr_tree, thresholds_tree = roc_curve(y_test, y_pred_prob_tree)
roc_auc_tree = auc(fpr_tree, tpr_tree)
plt.figure()
plt.plot(fpr_tree, tpr_tree, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc_tree)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# Comparar las métricas de ambos modelos
print("Regresión Logística:")
print(classification_report(y_test, y_pred))

print("Árboles de Decisión:")
print(classification_report(y_test, y_pred_tree))

# Comparar las curvas ROC
plt.figure()
plt.plot(fpr, tpr, color='blue', lw=2, label='Logistic Regression (area = %0.2f)' % roc_auc)
plt.plot(fpr_tree, tpr_tree, color='green', lw=2, label='Decision Tree (area = %0.2f)' % roc_auc_tree)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
